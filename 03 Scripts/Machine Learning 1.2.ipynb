# %% [markdown]
# # Import and Setup

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Path and Data

# %%
path = r'C:\Users\rubix\Downloads\Machine Learning 1'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Dataset-weather-prediction-dataset-processed.csv'), index_col = False)

# %% [markdown]
# # Checks Before Scaling

# %%
# Define what a quick check does

def quick_data_check(df, n_top_values=5):
    print("=== Shape ===")
    print(df.shape)
    print("\n=== Data Types ===")
    print(df.dtypes)
    
    print("\n=== First 5 Rows ===")
    print(df.head())
    
    print("\n=== Missing Values ===")
    print(df.isnull().sum())
    
    print("\n=== Basic Stats (Numeric Columns) ===")
    print(df.describe())
    
    print("\n=== Extended Numeric Summary ===")
    print(df.select_dtypes(include='number').agg(['mean', 'median', 'min', 'max']))
    
    print("\n=== Constant Columns ===")
    constant_cols = [col for col in df.columns if df[col].nunique() == 1]
    print(constant_cols if constant_cols else "None")
    
    print("\n=== Mixed Data Types Check ===")
    for column in df.columns:
        inferred_type = pd.api.types.infer_dtype(df[column])
        print(f"Column '{column}': {inferred_type}")
        if inferred_type in ['mixed', 'mixed-integer']:
            print(f"  --> Column '{column}' has mixed data types.")  # Fixed indentation here
    
    print("\n=== Duplicate Row Counts ===")
    print(df.duplicated().value_counts())
    
    print("\n=== Top Values for Categorical Columns ===")
    for col in df.select_dtypes(include='object'):
        print(f"\nColumn: {col}")
        print(df[col].value_counts(dropna=False).head(n_top_values))
    
    print("\n=== Correlation Matrix (Numeric Only) ===")
    print(df.corr(numeric_only=True))

# Use quick_data_check(df) to call data

# %%
quick_data_check(df)
# Out:
# === Shape ===
# (22950, 170)
#
# === Data Types ===
# DATE                     int64
# MONTH                    int64
# BASEL_cloud_cover        int64
# BASEL_wind_speed       float64
# BASEL_humidity         float64
#                         ...
# VALENTIA_snow_depth      int64
# VALENTIA_sunshine      float64
# VALENTIA_temp_mean     float64
# VALENTIA_temp_min      float64
# VALENTIA_temp_max      float64
# Length: 170, dtype: object
#
# === First 5 Rows ===
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# 1                 0             1.1  ...                     7
# 2                 0             0.0  ...                     7
# 3                 0             4.1  ...                     7
# 4                 0             5.4  ...                     3
#
#    VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0               0.88             1.0003                       0.45
# 1               0.91             1.0007                       0.25
# 2               0.91             1.0096                       0.17
# 3               0.86             1.0184                       0.13
# 4               0.80             1.0328                       0.46
#
#    VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                    0.34                    0                4.7
# 1                    0.84                    0                0.7
# 2                    0.08                    0                0.1
# 3                    0.98                    0                0.0
# 4                    0.00                    0                5.7
#
#    VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0                 8.5                6.0               10.9
# 1                 8.9                5.6               12.1
# 2                10.5                8.1               12.9
# 3                 7.4                7.3               10.6
# 4                 5.7                3.0                8.4
#
# [5 rows x 170 columns]
#
# === Missing Values ===
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64
#
# === Basic Stats (Numeric Columns) ===
#                DATE         MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# count  2.295000e+04  22950.000000       22950.000000      22950.000000
# mean   1.990984e+07      6.509630           5.410763          2.120462
# std    1.813833e+05      3.443672           2.406115          0.732625
# min    1.960010e+07      1.000000           0.000000          0.000000
# 25%    1.975092e+07      4.000000           4.000000          2.100000
# 50%    1.991060e+07      7.000000           6.000000          2.100000
# 75%    2.007021e+07      9.000000           7.000000          2.100000
# max    2.022103e+07     12.000000           8.000000         16.300000
#
#        BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# count    22950.000000    22950.000000            22950.000000
# mean         0.758554        1.018013                1.345244
# std          0.110699        0.006543                0.931158
# min          0.350000        0.974700                0.010000
# 25%          0.680000        1.015800                0.540000
# 50%          0.770000        1.018000                1.130000
# 75%          0.840000        1.020100                2.070000
# max          1.000000        1.045200                4.560000
#
#        BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  ...  \
# count         22950.000000      22950.000000    22950.000000  ...
# mean              0.222305          0.359564        4.592222  ...
# std               0.498995          2.006231        4.310808  ...
# min               0.000000         -2.000000        0.000000  ...
# 25%               0.000000          0.000000        0.400000  ...
# 50%               0.000000          0.000000        3.600000  ...
# 75%               0.220000          0.000000        7.900000  ...
# max               8.500000         49.000000       16.800000  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# count          22950.000000       22950.000000       22950.000000
# mean               5.723355           0.825824           1.014242
# std                1.630313           0.071121           0.010727
# min                0.000000           0.380000           0.955100
# 25%                5.000000           0.790000           1.009400
# 50%                6.000000           0.820000           1.014200
# 75%                7.000000           0.870000           1.020900
# max                8.000000           1.000000           1.046300
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# count               22950.000000            22950.000000         22950.000000
# mean                    1.134490                0.414698             0.001220
# std                     0.848813                0.844943             0.049383
# min                     0.020000                0.000000             0.000000
# 25%                     0.400000                0.010000             0.000000
# 50%                     0.970000                0.280000             0.000000
# 75%                     1.700000                0.410000             0.000000
# max                     3.980000               90.000000             3.000000
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# count       22950.000000        22950.000000       22950.000000
# mean            3.460989           10.724257           7.901904
# std             3.329432            3.328727           3.659393
# min             0.000000           -3.500000          -7.300000
# 25%             0.500000            8.800000           6.100000
# 50%             3.400000           10.700000           7.900000
# 75%             4.800000           13.000000          10.300000
# max            15.800000           23.600000          19.500000
#
#        VALENTIA_temp_max
# count       22950.000000
# mean           13.515752
# std             3.477373
# min            -1.500000
# 25%            11.300000
# 50%            13.500000
# 75%            15.700000
# max            28.400000
#
# [8 rows x 170 columns]
#
# === Extended Numeric Summary ===
#                 DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# mean    1.990984e+07   6.50963           5.410763          2.120462
# median  1.991060e+07   7.00000           6.000000          2.100000
# min     1.960010e+07   1.00000           0.000000          0.000000
# max     2.022103e+07  12.00000           8.000000         16.300000
#
#         BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# mean          0.758554        1.018013                1.345244
# median        0.770000        1.018000                1.130000
# min           0.350000        0.974700                0.010000
# max           1.000000        1.045200                4.560000
#
#         BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  ...  \
# mean               0.222305          0.359564        4.592222  ...
# median             0.000000          0.000000        3.600000  ...
# min                0.000000         -2.000000        0.000000  ...
# max                8.500000         49.000000       16.800000  ...
#
#         VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# mean                5.723355           0.825824           1.014242
# median              6.000000           0.820000           1.014200
# min                 0.000000           0.380000           0.955100
# max                 8.000000           1.000000           1.046300
#
#         VALENTIA_global_radiation  VALENTIA_precipitation  \
# mean                      1.13449                0.414698
# median                    0.97000                0.280000
# min                       0.02000                0.000000
# max                       3.98000               90.000000
#
#         VALENTIA_snow_depth  VALENTIA_sunshine  VALENTIA_temp_mean  \
# mean                0.00122           3.460989           10.724257
# median              0.00000           3.400000           10.700000
# min                 0.00000           0.000000           -3.500000
# max                 3.00000          15.800000           23.600000
#
#         VALENTIA_temp_min  VALENTIA_temp_max
# mean             7.901904          13.515752
# median           7.900000          13.500000
# min             -7.300000          -1.500000
# max             19.500000          28.400000
#
# [4 rows x 170 columns]
#
# === Constant Columns ===
# None
#
# === Mixed Data Types Check ===
# Column 'DATE': integer
# Column 'MONTH': integer
# Column 'BASEL_cloud_cover': integer
# Column 'BASEL_wind_speed': floating
# Column 'BASEL_humidity': floating
# Column 'BASEL_pressure': floating
# Column 'BASEL_global_radiation': floating
# Column 'BASEL_precipitation': floating
# Column 'BASEL_snow_depth': integer
# Column 'BASEL_sunshine': floating
# Column 'BASEL_temp_mean': floating
# Column 'BASEL_temp_min': floating
# Column 'BASEL_temp_max': floating
# Column 'BELGRADE_cloud_cover': integer
# Column 'BELGRADE_humidity': floating
# Column 'BELGRADE_pressure': floating
# Column 'BELGRADE_global_radiation': floating
# Column 'BELGRADE_precipitation': floating
# Column 'BELGRADE_sunshine': floating
# Column 'BELGRADE_temp_mean': floating
# Column 'BELGRADE_temp_min': floating
# Column 'BELGRADE_temp_max': floating
# Column 'BUDAPEST_cloud_cover': integer
# Column 'BUDAPEST_humidity': floating
# Column 'BUDAPEST_pressure': floating
# Column 'BUDAPEST_global_radiation': floating
# Column 'BUDAPEST_precipitation': floating
# Column 'BUDAPEST_sunshine': floating
# Column 'BUDAPEST_temp_mean': floating
# Column 'BUDAPEST_temp_min': floating
# Column 'BUDAPEST_temp_max': floating
# Column 'DEBILT_cloud_cover': integer
# Column 'DEBILT_wind_speed': floating
# Column 'DEBILT_humidity': floating
# Column 'DEBILT_pressure': floating
# Column 'DEBILT_global_radiation': floating
# Column 'DEBILT_precipitation': floating
# Column 'DEBILT_sunshine': floating
# Column 'DEBILT_temp_mean': floating
# Column 'DEBILT_temp_min': floating
# Column 'DEBILT_temp_max': floating
# Column 'DUSSELDORF_cloud_cover': integer
# Column 'DUSSELDORF_wind_speed': floating
# Column 'DUSSELDORF_humidity': floating
# Column 'DUSSELDORF_pressure': floating
# Column 'DUSSELDORF_global_radiation': floating
# Column 'DUSSELDORF_precipitation': floating
# Column 'DUSSELDORF_snow_depth': integer
# Column 'DUSSELDORF_sunshine': floating
# Column 'DUSSELDORF_temp_mean': floating
# Column 'DUSSELDORF_temp_min': floating
# Column 'DUSSELDORF_temp_max': floating
# Column 'GDANSK_cloud_cover': integer
# Column 'GDANSK_humidity': floating
# Column 'GDANSK_precipitation': floating
# Column 'GDANSK_snow_depth': integer
# Column 'GDANSK_temp_mean': floating
# Column 'GDANSK_temp_min': floating
# Column 'GDANSK_temp_max': floating
# Column 'HEATHROW_cloud_cover': integer
# Column 'HEATHROW_humidity': floating
# Column 'HEATHROW_pressure': floating
# Column 'HEATHROW_global_radiation': floating
# Column 'HEATHROW_precipitation': floating
# Column 'HEATHROW_snow_depth': integer
# Column 'HEATHROW_sunshine': floating
# Column 'HEATHROW_temp_mean': floating
# Column 'HEATHROW_temp_min': floating
# Column 'HEATHROW_temp_max': floating
# Column 'KASSEL_wind_speed': floating
# Column 'KASSEL_humidity': floating
# Column 'KASSEL_pressure': floating
# Column 'KASSEL_global_radiation': floating
# Column 'KASSEL_precipitation': floating
# Column 'KASSEL_sunshine': floating
# Column 'KASSEL_temp_mean': floating
# Column 'KASSEL_temp_min': floating
# Column 'KASSEL_temp_max': floating
# Column 'LJUBLJANA_cloud_cover': integer
# Column 'LJUBLJANA_wind_speed': floating
# Column 'LJUBLJANA_humidity': floating
# Column 'LJUBLJANA_pressure': floating
# Column 'LJUBLJANA_global_radiation': floating
# Column 'LJUBLJANA_precipitation': floating
# Column 'LJUBLJANA_sunshine': floating
# Column 'LJUBLJANA_temp_mean': floating
# Column 'LJUBLJANA_temp_min': floating
# Column 'LJUBLJANA_temp_max': floating
# Column 'MAASTRICHT_cloud_cover': integer
# Column 'MAASTRICHT_wind_speed': floating
# Column 'MAASTRICHT_humidity': floating
# Column 'MAASTRICHT_pressure': floating
# Column 'MAASTRICHT_global_radiation': floating
# Column 'MAASTRICHT_precipitation': floating
# Column 'MAASTRICHT_sunshine': floating
# Column 'MAASTRICHT_temp_mean': floating
# Column 'MAASTRICHT_temp_min': floating
# Column 'MAASTRICHT_temp_max': floating
# Column 'MADRID_cloud_cover': integer
# Column 'MADRID_wind_speed': floating
# Column 'MADRID_humidity': floating
# Column 'MADRID_pressure': floating
# Column 'MADRID_global_radiation': floating
# Column 'MADRID_precipitation': floating
# Column 'MADRID_sunshine': floating
# Column 'MADRID_temp_mean': floating
# Column 'MADRID_temp_min': floating
# Column 'MADRID_temp_max': floating
# Column 'MUNCHENB_cloud_cover': integer
# Column 'MUNCHENB_humidity': floating
# Column 'MUNCHENB_global_radiation': floating
# Column 'MUNCHENB_precipitation': floating
# Column 'MUNCHENB_snow_depth': integer
# Column 'MUNCHENB_sunshine': floating
# Column 'MUNCHENB_temp_mean': floating
# Column 'MUNCHENB_temp_min': floating
# Column 'MUNCHENB_temp_max': floating
# Column 'OSLO_cloud_cover': integer
# Column 'OSLO_wind_speed': floating
# Column 'OSLO_humidity': floating
# Column 'OSLO_pressure': floating
# Column 'OSLO_global_radiation': floating
# Column 'OSLO_precipitation': floating
# Column 'OSLO_snow_depth': integer
# Column 'OSLO_sunshine': floating
# Column 'OSLO_temp_mean': floating
# Column 'OSLO_temp_min': floating
# Column 'OSLO_temp_max': floating
# Column 'ROMA_cloud_cover': integer
# Column 'ROMA_wind_speed': floating
# Column 'ROMA_humidity': floating
# Column 'ROMA_pressure': floating
# Column 'ROMA_sunshine': floating
# Column 'ROMA_temp_mean': floating
# Column 'SONNBLICK_cloud_cover': integer
# Column 'SONNBLICK_wind_speed': floating
# Column 'SONNBLICK_humidity': floating
# Column 'SONNBLICK_pressure': floating
# Column 'SONNBLICK_global_radiation': floating
# Column 'SONNBLICK_precipitation': floating
# Column 'SONNBLICK_sunshine': floating
# Column 'SONNBLICK_temp_mean': floating
# Column 'SONNBLICK_temp_min': floating
# Column 'SONNBLICK_temp_max': floating
# Column 'STOCKHOLM_cloud_cover': integer
# Column 'STOCKHOLM_pressure': floating
# Column 'STOCKHOLM_global_radiation': floating
# Column 'STOCKHOLM_precipitation': floating
# Column 'STOCKHOLM_sunshine': floating
# Column 'STOCKHOLM_temp_mean': floating
# Column 'STOCKHOLM_temp_min': floating
# Column 'STOCKHOLM_temp_max': floating
# Column 'TOURS_wind_speed': floating
# Column 'TOURS_humidity': floating
# Column 'TOURS_pressure': floating
# Column 'TOURS_global_radiation': floating
# Column 'TOURS_precipitation': floating
# Column 'TOURS_temp_mean': floating
# Column 'TOURS_temp_min': floating
# Column 'TOURS_temp_max': floating
# Column 'VALENTIA_cloud_cover': integer
# Column 'VALENTIA_humidity': floating
# Column 'VALENTIA_pressure': floating
# Column 'VALENTIA_global_radiation': floating
# Column 'VALENTIA_precipitation': floating
# Column 'VALENTIA_snow_depth': integer
# Column 'VALENTIA_sunshine': floating
# Column 'VALENTIA_temp_mean': floating
# Column 'VALENTIA_temp_min': floating
# Column 'VALENTIA_temp_max': floating
#
# === Duplicate Row Counts ===
# False    22950
# Name: count, dtype: int64
#
# === Top Values for Categorical Columns ===
#
# === Correlation Matrix (Numeric Only) ===
#                          DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# DATE                 1.000000 -0.004645          -0.002512         -0.030039
# MONTH               -0.004645  1.000000          -0.010051         -0.056560
# BASEL_cloud_cover   -0.002512 -0.010051           1.000000          0.088132
# BASEL_wind_speed    -0.030039 -0.056560           0.088132          1.000000
# BASEL_humidity      -0.158055  0.204943           0.478339         -0.043173
# ...                       ...       ...                ...               ...
# VALENTIA_snow_depth -0.011177 -0.027230           0.018519         -0.001894
# VALENTIA_sunshine    0.002312 -0.063997          -0.054276         -0.026333
# VALENTIA_temp_mean   0.049756  0.260952          -0.229722         -0.066430
# VALENTIA_temp_min    0.060978  0.252235          -0.205169         -0.049316
# VALENTIA_temp_max    0.030676  0.233360          -0.231702         -0.086405
#
#                      BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# DATE                      -0.158055       -0.013805                0.035461
# MONTH                      0.204943       -0.011526               -0.084257
# BASEL_cloud_cover          0.478339       -0.237181               -0.557135
# BASEL_wind_speed          -0.043173       -0.108880               -0.141369
# BASEL_humidity             1.000000       -0.015672               -0.669454
# ...                             ...             ...                     ...
# VALENTIA_snow_depth        0.023917       -0.018187               -0.025564
# VALENTIA_sunshine         -0.161270       -0.119781                0.276848
# VALENTIA_temp_mean        -0.215890        0.057856                0.514115
# VALENTIA_temp_min         -0.185348        0.063084                0.436514
# VALENTIA_temp_max         -0.227038        0.048910                0.538005
#
#                      BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  \
# DATE                            0.014616         -0.045162        0.048019
# MONTH                           0.023427         -0.123970       -0.018046
# BASEL_cloud_cover               0.286687          0.057992       -0.820493
# BASEL_wind_speed                0.061820         -0.006832       -0.134611
# BASEL_humidity                  0.250480          0.115772       -0.658552
# ...                                  ...               ...             ...
# VALENTIA_snow_depth            -0.001723          0.059346       -0.021100
# VALENTIA_sunshine               0.076509         -0.062937        0.147237
# VALENTIA_temp_mean             -0.006594         -0.246007        0.372199
# VALENTIA_temp_min              -0.001913         -0.232000        0.325030
# VALENTIA_temp_max              -0.011740         -0.238384        0.380837
#
#                      ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# DATE                 ...             -0.156104          -0.043615
# MONTH                ...              0.017313           0.121805
# BASEL_cloud_cover    ...             -0.008221          -0.048232
# BASEL_wind_speed     ...              0.040438          -0.039129
# BASEL_humidity       ...              0.028580           0.048392
# ...                  ...                   ...                ...
# VALENTIA_snow_depth  ...             -0.027740          -0.001651
# VALENTIA_sunshine    ...             -0.737591          -0.440758
# VALENTIA_temp_mean   ...              0.170054           0.261735
# VALENTIA_temp_min    ...              0.325158           0.301572
# VALENTIA_temp_max    ...             -0.015424           0.185257
#
#                      VALENTIA_pressure  VALENTIA_global_radiation  \
# DATE                          0.007671                  -0.028219
# MONTH                        -0.010884                  -0.115122
# BASEL_cloud_cover            -0.053435                  -0.110207
# BASEL_wind_speed             -0.057346                  -0.084606
# BASEL_humidity               -0.005714                  -0.333133
# ...                                ...                        ...
# VALENTIA_snow_depth          -0.004721                  -0.016857
# VALENTIA_sunshine             0.186835                   0.757447
# VALENTIA_temp_mean            0.098454                   0.398215
# VALENTIA_temp_min             0.030026                   0.250858
# VALENTIA_temp_max             0.149390                   0.510864
#
#                      VALENTIA_precipitation  VALENTIA_snow_depth  \
# DATE                               0.023990            -0.011177
# MONTH                              0.020220            -0.027230
# BASEL_cloud_cover                  0.012231             0.018519
# BASEL_wind_speed                   0.003375            -0.001894
# BASEL_humidity                     0.045847             0.023917
# ...                                     ...                  ...
# VALENTIA_snow_depth               -0.007991             1.000000
# VALENTIA_sunshine                 -0.204202             0.000793
# VALENTIA_temp_mean                -0.039292            -0.077080
# VALENTIA_temp_min                 -0.019308            -0.072737
# VALENTIA_temp_max                 -0.065125            -0.071720
#
#                      VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# DATE                          0.002312            0.049756           0.060978
# MONTH                        -0.063997            0.260952           0.252235
# BASEL_cloud_cover            -0.054276           -0.229722          -0.205169
# BASEL_wind_speed             -0.026333           -0.066430          -0.049316
# BASEL_humidity               -0.161270           -0.215890          -0.185348
# ...                                ...                 ...                ...
# VALENTIA_snow_depth           0.000793           -0.077080          -0.072737
# VALENTIA_sunshine             1.000000            0.159709          -0.006798
# VALENTIA_temp_mean            0.159709            1.000000           0.942297
# VALENTIA_temp_min            -0.006798            0.942297           1.000000
# VALENTIA_temp_max             0.314919            0.925102           0.764379
#
#                      VALENTIA_temp_max
# DATE                          0.030676
# MONTH                         0.233360
# BASEL_cloud_cover            -0.231702
# BASEL_wind_speed             -0.086405
# BASEL_humidity               -0.227038
# ...                                ...
# VALENTIA_snow_depth          -0.071720
# VALENTIA_sunshine             0.314919
# VALENTIA_temp_mean            0.925102
# VALENTIA_temp_min             0.764379
# VALENTIA_temp_max             1.000000
#
# [170 rows x 170 columns]

# %% [markdown]
# ## Summary of quick_data_check(df)

# %% [markdown]
# Nothing too crazy at first glance. I could maybe make a case for the date to be NOT an int64 type, but I think it's fine at the moment with the preferred YYYYMMDD format.
#
# Obviously I can't see literally all 170 columns at once using this method, but at least I get the names. It might be worth checking to see if all locations have the same number of columns.
#
# The correlation matrix is also kind of funny. I'm sure the correlations are going to be silly, but maybe a heatmap to see it better? Might be better after scaling so let's do that first.

# %% [markdown]
# # Scaling

# %% [markdown]
# ## Separate Data

# %% [markdown]
# I don't seen any object/string types so I shouldn't have to limit to numerical only, but we'll check anyway. Should be 22950, 170 when done.

# %%
df_num = df.select_dtypes(include=np.number)

# %%
df_num.shape
# Out:
# (22950, 170)

# %% [markdown]
# Passed, awesome. Since I don't need that, I'll go ahead and delete it.

# %%
del df_num

# %% [markdown]
# That being said, we may have to return to the standard format for the DATE and MONTH columns eventually for practical displaying of data. I'll skip it for now.

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
# Use the column names from the original dataframe
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %% [markdown]
# ## Checks

# %%
df_scaled.head()
# Out:
#        DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0 -1.707663 -1.599964           0.660514          -0.02793        0.826097
# 1 -1.707657 -1.599964           0.244897          -0.02793        0.735760
# 2 -1.707652 -1.599964           1.076130          -0.02793        1.277781
# 3 -1.707646 -1.599964          -1.001953          -0.02793        1.458455
# 4 -1.707641 -1.599964           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# 1         -0.179228       -0.810126  ...              0.783085
# 2         -0.179228       -1.065304  ...              0.783085
# 3         -0.179228       -0.114186  ...              0.783085
# 4         -0.179228        0.187388  ...             -1.670486
#
#    VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0           0.761754          -1.299744                  -0.806427
# 1           1.183580          -1.262455                  -1.042055
# 2           1.183580          -0.432779                  -1.136306
# 3           0.480538           0.387574                  -1.183432
# 4          -0.363113           1.729970                  -0.794645
#
#    VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0               -0.088407            -0.024706           0.372147
# 1                0.503361            -0.024706          -0.829285
# 2               -0.396127            -0.024706          -1.009500
# 3                0.669056            -0.024706          -1.039536
# 4               -0.490810            -0.024706           0.672505
#
#    VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0           -0.668215          -0.519743          -0.752237
# 1           -0.548046          -0.629054          -0.407141
# 2           -0.067372           0.054135          -0.177078
# 3           -0.998679          -0.164486          -0.838511
# 4           -1.509396          -1.339569          -1.471186
#
# [5 rows x 170 columns]

# %%
quick_data_check(df_scaled)
# Out:
# === Shape ===
# (22950, 170)
#
# === Data Types ===
# DATE                   float64
# MONTH                  float64
# BASEL_cloud_cover      float64
# BASEL_wind_speed       float64
# BASEL_humidity         float64
#                         ...
# VALENTIA_snow_depth    float64
# VALENTIA_sunshine      float64
# VALENTIA_temp_mean     float64
# VALENTIA_temp_min      float64
# VALENTIA_temp_max      float64
# Length: 170, dtype: object
#
# === First 5 Rows ===
#        DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0 -1.707663 -1.599964           0.660514          -0.02793        0.826097
# 1 -1.707657 -1.599964           0.244897          -0.02793        0.735760
# 2 -1.707652 -1.599964           1.076130          -0.02793        1.277781
# 3 -1.707646 -1.599964          -1.001953          -0.02793        1.458455
# 4 -1.707641 -1.599964           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# 1         -0.179228       -0.810126  ...              0.783085
# 2         -0.179228       -1.065304  ...              0.783085
# 3         -0.179228       -0.114186  ...              0.783085
# 4         -0.179228        0.187388  ...             -1.670486
#
#    VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0           0.761754          -1.299744                  -0.806427
# 1           1.183580          -1.262455                  -1.042055
# 2           1.183580          -0.432779                  -1.136306
# 3           0.480538           0.387574                  -1.183432
# 4          -0.363113           1.729970                  -0.794645
#
#    VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0               -0.088407            -0.024706           0.372147
# 1                0.503361            -0.024706          -0.829285
# 2               -0.396127            -0.024706          -1.009500
# 3                0.669056            -0.024706          -1.039536
# 4               -0.490810            -0.024706           0.672505
#
#    VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0           -0.668215          -0.519743          -0.752237
# 1           -0.548046          -0.629054          -0.407141
# 2           -0.067372           0.054135          -0.177078
# 3           -0.998679          -0.164486          -0.838511
# 4           -1.509396          -1.339569          -1.471186
#
# [5 rows x 170 columns]
#
# === Missing Values ===
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64
#
# === Basic Stats (Numeric Columns) ===
#                DATE         MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# count  2.295000e+04  2.295000e+04       2.295000e+04      2.295000e+04
# mean  -3.566646e-15  3.715256e-18      -1.975278e-16     -8.817541e-16
# std    1.000022e+00  1.000022e+00       1.000022e+00      1.000022e+00
# min   -1.707663e+00 -1.599964e+00      -2.248803e+00     -2.894398e+00
# 25%   -8.761721e-01 -7.287815e-01      -5.863365e-01     -2.793014e-02
# 50%    4.221783e-03  1.424006e-01       2.448969e-01     -2.793014e-02
# 75%    8.842187e-01  7.231887e-01       6.605137e-01     -2.793014e-02
# max    1.715715e+00  1.594371e+00       1.076130e+00      1.935485e+01
#
#        BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# count    2.295000e+04    2.295000e+04            2.295000e+04
# mean     6.935145e-16   -1.690442e-15           -2.179617e-16
# std      1.000022e+00    1.000022e+00            1.000022e+00
# min     -3.690749e+00   -6.619945e+00           -1.433992e+00
# 25%     -7.096309e-01   -3.381979e-01           -8.647959e-01
# 50%      1.034013e-01   -1.948634e-03           -2.311624e-01
# 75%      7.357597e-01    3.190165e-01            7.783554e-01
# max      2.181150e+00    4.155315e+00            3.452504e+00
#
#        BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  ...  \
# count         2.295000e+04      2.295000e+04    2.295000e+04  ...
# mean         -6.997066e-17     -4.953675e-18   -3.962940e-17  ...
# std           1.000022e+00      1.000022e+00    1.000022e+00  ...
# min          -4.455141e-01     -1.176144e+00   -1.065304e+00  ...
# 25%          -4.455141e-01     -1.792277e-01   -9.725122e-01  ...
# 50%          -4.455141e-01     -1.792277e-01   -2.301758e-01  ...
# 75%          -4.618532e-03     -1.792277e-01    7.673387e-01  ...
# max           1.658909e+01      2.424521e+01    2.831962e+00  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# count          2.295000e+04       2.295000e+04       2.295000e+04
# mean          -1.486102e-16      -1.709018e-15      -1.800104e-14
# std            1.000022e+00       1.000022e+00       1.000022e+00
# min           -3.510664e+00      -6.268665e+00      -5.513376e+00
# 25%           -4.437007e-01      -5.037211e-01      -4.514238e-01
# 50%            1.696919e-01      -8.189596e-02      -3.958379e-03
# 75%            7.830846e-01       6.211460e-01       6.206288e-01
# max            1.396477e+00       2.449055e+00       2.988467e+00
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# count               2.295000e+04            2.295000e+04         2.295000e+04
# mean               -1.368453e-16           -1.238419e-18         4.953675e-18
# std                 1.000022e+00            1.000022e+00         1.000022e+00
# min                -1.313028e+00           -4.908101e-01        -2.470616e-02
# 25%                -8.653338e-01           -4.789747e-01        -2.470616e-02
# 50%                -1.937928e-01           -1.594196e-01        -2.470616e-02
# 75%                 6.662509e-01           -5.559789e-03        -2.470616e-02
# max                 3.352415e+00            1.060275e+02         6.072597e+01
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# count       2.295000e+04        2.295000e+04       2.295000e+04
# mean        1.733786e-17        4.458307e-17      -1.535639e-16
# std         1.000022e+00        1.000022e+00       1.000022e+00
# min        -1.039536e+00       -4.273275e+00      -4.154305e+00
# 25%        -8.893570e-01       -5.780885e-01      -4.924159e-01
# 50%        -1.831857e-02       -7.287352e-03      -5.203543e-04
# 75%         4.021827e-01        6.836824e-01       6.553403e-01
# max         3.706122e+00        3.868152e+00       3.169473e+00
#
#        VALENTIA_temp_max
# count       2.295000e+04
# mean       -1.356068e-16
# std         1.000022e+00
# min        -4.318225e+00
# 25%        -6.372051e-01
# 50%        -4.529850e-03
# 75%         6.281454e-01
# max         4.280407e+00
#
# [8 rows x 170 columns]
#
# === Extended Numeric Summary ===
#                 DATE         MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# mean   -3.566646e-15  3.715256e-18      -1.975278e-16     -8.817541e-16
# median  4.221783e-03  1.424006e-01       2.448969e-01     -2.793014e-02
# min    -1.707663e+00 -1.599964e+00      -2.248803e+00     -2.894398e+00
# max     1.715715e+00  1.594371e+00       1.076130e+00      1.935485e+01
#
#         BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# mean      6.935145e-16   -1.690442e-15           -2.179617e-16
# median    1.034013e-01   -1.948634e-03           -2.311624e-01
# min      -3.690749e+00   -6.619945e+00           -1.433992e+00
# max       2.181150e+00    4.155315e+00            3.452504e+00
#
#         BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  ...  \
# mean          -6.997066e-17     -4.953675e-18   -3.962940e-17  ...
# median        -4.455141e-01     -1.792277e-01   -2.301758e-01  ...
# min           -4.455141e-01     -1.176144e+00   -1.065304e+00  ...
# max            1.658909e+01      2.424521e+01    2.831962e+00  ...
#
#         VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# mean           -1.486102e-16      -1.709018e-15      -1.800104e-14
# median          1.696919e-01      -8.189596e-02      -3.958379e-03
# min            -3.510664e+00      -6.268665e+00      -5.513376e+00
# max             1.396477e+00       2.449055e+00       2.988467e+00
#
#         VALENTIA_global_radiation  VALENTIA_precipitation  \
# mean                -1.368453e-16           -1.238419e-18
# median              -1.937928e-01           -1.594196e-01
# min                 -1.313028e+00           -4.908101e-01
# max                  3.352415e+00            1.060275e+02
#
#         VALENTIA_snow_depth  VALENTIA_sunshine  VALENTIA_temp_mean  \
# mean           4.953675e-18       1.733786e-17        4.458307e-17
# median        -2.470616e-02      -1.831857e-02       -7.287352e-03
# min           -2.470616e-02      -1.039536e+00       -4.273275e+00
# max            6.072597e+01       3.706122e+00        3.868152e+00
#
#         VALENTIA_temp_min  VALENTIA_temp_max
# mean        -1.535639e-16      -1.356068e-16
# median      -5.203543e-04      -4.529850e-03
# min         -4.154305e+00      -4.318225e+00
# max          3.169473e+00       4.280407e+00
#
# [4 rows x 170 columns]
#
# === Constant Columns ===
# None
#
# === Mixed Data Types Check ===
# Column 'DATE': floating
# Column 'MONTH': floating
# Column 'BASEL_cloud_cover': floating
# Column 'BASEL_wind_speed': floating
# Column 'BASEL_humidity': floating
# Column 'BASEL_pressure': floating
# Column 'BASEL_global_radiation': floating
# Column 'BASEL_precipitation': floating
# Column 'BASEL_snow_depth': floating
# Column 'BASEL_sunshine': floating
# Column 'BASEL_temp_mean': floating
# Column 'BASEL_temp_min': floating
# Column 'BASEL_temp_max': floating
# Column 'BELGRADE_cloud_cover': floating
# Column 'BELGRADE_humidity': floating
# Column 'BELGRADE_pressure': floating
# Column 'BELGRADE_global_radiation': floating
# Column 'BELGRADE_precipitation': floating
# Column 'BELGRADE_sunshine': floating
# Column 'BELGRADE_temp_mean': floating
# Column 'BELGRADE_temp_min': floating
# Column 'BELGRADE_temp_max': floating
# Column 'BUDAPEST_cloud_cover': floating
# Column 'BUDAPEST_humidity': floating
# Column 'BUDAPEST_pressure': floating
# Column 'BUDAPEST_global_radiation': floating
# Column 'BUDAPEST_precipitation': floating
# Column 'BUDAPEST_sunshine': floating
# Column 'BUDAPEST_temp_mean': floating
# Column 'BUDAPEST_temp_min': floating
# Column 'BUDAPEST_temp_max': floating
# Column 'DEBILT_cloud_cover': floating
# Column 'DEBILT_wind_speed': floating
# Column 'DEBILT_humidity': floating
# Column 'DEBILT_pressure': floating
# Column 'DEBILT_global_radiation': floating
# Column 'DEBILT_precipitation': floating
# Column 'DEBILT_sunshine': floating
# Column 'DEBILT_temp_mean': floating
# Column 'DEBILT_temp_min': floating
# Column 'DEBILT_temp_max': floating
# Column 'DUSSELDORF_cloud_cover': floating
# Column 'DUSSELDORF_wind_speed': floating
# Column 'DUSSELDORF_humidity': floating
# Column 'DUSSELDORF_pressure': floating
# Column 'DUSSELDORF_global_radiation': floating
# Column 'DUSSELDORF_precipitation': floating
# Column 'DUSSELDORF_snow_depth': floating
# Column 'DUSSELDORF_sunshine': floating
# Column 'DUSSELDORF_temp_mean': floating
# Column 'DUSSELDORF_temp_min': floating
# Column 'DUSSELDORF_temp_max': floating
# Column 'GDANSK_cloud_cover': floating
# Column 'GDANSK_humidity': floating
# Column 'GDANSK_precipitation': floating
# Column 'GDANSK_snow_depth': floating
# Column 'GDANSK_temp_mean': floating
# Column 'GDANSK_temp_min': floating
# Column 'GDANSK_temp_max': floating
# Column 'HEATHROW_cloud_cover': floating
# Column 'HEATHROW_humidity': floating
# Column 'HEATHROW_pressure': floating
# Column 'HEATHROW_global_radiation': floating
# Column 'HEATHROW_precipitation': floating
# Column 'HEATHROW_snow_depth': floating
# Column 'HEATHROW_sunshine': floating
# Column 'HEATHROW_temp_mean': floating
# Column 'HEATHROW_temp_min': floating
# Column 'HEATHROW_temp_max': floating
# Column 'KASSEL_wind_speed': floating
# Column 'KASSEL_humidity': floating
# Column 'KASSEL_pressure': floating
# Column 'KASSEL_global_radiation': floating
# Column 'KASSEL_precipitation': floating
# Column 'KASSEL_sunshine': floating
# Column 'KASSEL_temp_mean': floating
# Column 'KASSEL_temp_min': floating
# Column 'KASSEL_temp_max': floating
# Column 'LJUBLJANA_cloud_cover': floating
# Column 'LJUBLJANA_wind_speed': floating
# Column 'LJUBLJANA_humidity': floating
# Column 'LJUBLJANA_pressure': floating
# Column 'LJUBLJANA_global_radiation': floating
# Column 'LJUBLJANA_precipitation': floating
# Column 'LJUBLJANA_sunshine': floating
# Column 'LJUBLJANA_temp_mean': floating
# Column 'LJUBLJANA_temp_min': floating
# Column 'LJUBLJANA_temp_max': floating
# Column 'MAASTRICHT_cloud_cover': floating
# Column 'MAASTRICHT_wind_speed': floating
# Column 'MAASTRICHT_humidity': floating
# Column 'MAASTRICHT_pressure': floating
# Column 'MAASTRICHT_global_radiation': floating
# Column 'MAASTRICHT_precipitation': floating
# Column 'MAASTRICHT_sunshine': floating
# Column 'MAASTRICHT_temp_mean': floating
# Column 'MAASTRICHT_temp_min': floating
# Column 'MAASTRICHT_temp_max': floating
# Column 'MADRID_cloud_cover': floating
# Column 'MADRID_wind_speed': floating
# Column 'MADRID_humidity': floating
# Column 'MADRID_pressure': floating
# Column 'MADRID_global_radiation': floating
# Column 'MADRID_precipitation': floating
# Column 'MADRID_sunshine': floating
# Column 'MADRID_temp_mean': floating
# Column 'MADRID_temp_min': floating
# Column 'MADRID_temp_max': floating
# Column 'MUNCHENB_cloud_cover': floating
# Column 'MUNCHENB_humidity': floating
# Column 'MUNCHENB_global_radiation': floating
# Column 'MUNCHENB_precipitation': floating
# Column 'MUNCHENB_snow_depth': floating
# Column 'MUNCHENB_sunshine': floating
# Column 'MUNCHENB_temp_mean': floating
# Column 'MUNCHENB_temp_min': floating
# Column 'MUNCHENB_temp_max': floating
# Column 'OSLO_cloud_cover': floating
# Column 'OSLO_wind_speed': floating
# Column 'OSLO_humidity': floating
# Column 'OSLO_pressure': floating
# Column 'OSLO_global_radiation': floating
# Column 'OSLO_precipitation': floating
# Column 'OSLO_snow_depth': floating
# Column 'OSLO_sunshine': floating
# Column 'OSLO_temp_mean': floating
# Column 'OSLO_temp_min': floating
# Column 'OSLO_temp_max': floating
# Column 'ROMA_cloud_cover': floating
# Column 'ROMA_wind_speed': floating
# Column 'ROMA_humidity': floating
# Column 'ROMA_pressure': floating
# Column 'ROMA_sunshine': floating
# Column 'ROMA_temp_mean': floating
# Column 'SONNBLICK_cloud_cover': floating
# Column 'SONNBLICK_wind_speed': floating
# Column 'SONNBLICK_humidity': floating
# Column 'SONNBLICK_pressure': floating
# Column 'SONNBLICK_global_radiation': floating
# Column 'SONNBLICK_precipitation': floating
# Column 'SONNBLICK_sunshine': floating
# Column 'SONNBLICK_temp_mean': floating
# Column 'SONNBLICK_temp_min': floating
# Column 'SONNBLICK_temp_max': floating
# Column 'STOCKHOLM_cloud_cover': floating
# Column 'STOCKHOLM_pressure': floating
# Column 'STOCKHOLM_global_radiation': floating
# Column 'STOCKHOLM_precipitation': floating
# Column 'STOCKHOLM_sunshine': floating
# Column 'STOCKHOLM_temp_mean': floating
# Column 'STOCKHOLM_temp_min': floating
# Column 'STOCKHOLM_temp_max': floating
# Column 'TOURS_wind_speed': floating
# Column 'TOURS_humidity': floating
# Column 'TOURS_pressure': floating
# Column 'TOURS_global_radiation': floating
# Column 'TOURS_precipitation': floating
# Column 'TOURS_temp_mean': floating
# Column 'TOURS_temp_min': floating
# Column 'TOURS_temp_max': floating
# Column 'VALENTIA_cloud_cover': floating
# Column 'VALENTIA_humidity': floating
# Column 'VALENTIA_pressure': floating
# Column 'VALENTIA_global_radiation': floating
# Column 'VALENTIA_precipitation': floating
# Column 'VALENTIA_snow_depth': floating
# Column 'VALENTIA_sunshine': floating
# Column 'VALENTIA_temp_mean': floating
# Column 'VALENTIA_temp_min': floating
# Column 'VALENTIA_temp_max': floating
#
# === Duplicate Row Counts ===
# False    22950
# Name: count, dtype: int64
#
# === Top Values for Categorical Columns ===
#
# === Correlation Matrix (Numeric Only) ===
#                          DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  \
# DATE                 1.000000 -0.004645          -0.002512         -0.030039
# MONTH               -0.004645  1.000000          -0.010051         -0.056560
# BASEL_cloud_cover   -0.002512 -0.010051           1.000000          0.088132
# BASEL_wind_speed    -0.030039 -0.056560           0.088132          1.000000
# BASEL_humidity      -0.158055  0.204943           0.478339         -0.043173
# ...                       ...       ...                ...               ...
# VALENTIA_snow_depth -0.011177 -0.027230           0.018519         -0.001894
# VALENTIA_sunshine    0.002312 -0.063997          -0.054276         -0.026333
# VALENTIA_temp_mean   0.049756  0.260952          -0.229722         -0.066430
# VALENTIA_temp_min    0.060978  0.252235          -0.205169         -0.049316
# VALENTIA_temp_max    0.030676  0.233360          -0.231702         -0.086405
#
#                      BASEL_humidity  BASEL_pressure  BASEL_global_radiation  \
# DATE                      -0.158055       -0.013805                0.035461
# MONTH                      0.204943       -0.011526               -0.084257
# BASEL_cloud_cover          0.478339       -0.237181               -0.557135
# BASEL_wind_speed          -0.043173       -0.108880               -0.141369
# BASEL_humidity             1.000000       -0.015672               -0.669454
# ...                             ...             ...                     ...
# VALENTIA_snow_depth        0.023917       -0.018187               -0.025564
# VALENTIA_sunshine         -0.161270       -0.119781                0.276848
# VALENTIA_temp_mean        -0.215890        0.057856                0.514115
# VALENTIA_temp_min         -0.185348        0.063084                0.436514
# VALENTIA_temp_max         -0.227038        0.048910                0.538005
#
#                      BASEL_precipitation  BASEL_snow_depth  BASEL_sunshine  \
# DATE                            0.014616         -0.045162        0.048019
# MONTH                           0.023427         -0.123970       -0.018046
# BASEL_cloud_cover               0.286687          0.057992       -0.820493
# BASEL_wind_speed                0.061820         -0.006832       -0.134611
# BASEL_humidity                  0.250480          0.115772       -0.658552
# ...                                  ...               ...             ...
# VALENTIA_snow_depth            -0.001723          0.059346       -0.021100
# VALENTIA_sunshine               0.076509         -0.062937        0.147237
# VALENTIA_temp_mean             -0.006594         -0.246007        0.372199
# VALENTIA_temp_min              -0.001913         -0.232000        0.325030
# VALENTIA_temp_max              -0.011740         -0.238384        0.380837
#
#                      ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# DATE                 ...             -0.156104          -0.043615
# MONTH                ...              0.017313           0.121805
# BASEL_cloud_cover    ...             -0.008221          -0.048232
# BASEL_wind_speed     ...              0.040438          -0.039129
# BASEL_humidity       ...              0.028580           0.048392
# ...                  ...                   ...                ...
# VALENTIA_snow_depth  ...             -0.027740          -0.001651
# VALENTIA_sunshine    ...             -0.737591          -0.440758
# VALENTIA_temp_mean   ...              0.170054           0.261735
# VALENTIA_temp_min    ...              0.325158           0.301572
# VALENTIA_temp_max    ...             -0.015424           0.185257
#
#                      VALENTIA_pressure  VALENTIA_global_radiation  \
# DATE                          0.007671                  -0.028219
# MONTH                        -0.010884                  -0.115122
# BASEL_cloud_cover            -0.053435                  -0.110207
# BASEL_wind_speed             -0.057346                  -0.084606
# BASEL_humidity               -0.005714                  -0.333133
# ...                                ...                        ...
# VALENTIA_snow_depth          -0.004721                  -0.016857
# VALENTIA_sunshine             0.186835                   0.757447
# VALENTIA_temp_mean            0.098454                   0.398215
# VALENTIA_temp_min             0.030026                   0.250858
# VALENTIA_temp_max             0.149390                   0.510864
#
#                      VALENTIA_precipitation  VALENTIA_snow_depth  \
# DATE                               0.023990            -0.011177
# MONTH                              0.020220            -0.027230
# BASEL_cloud_cover                  0.012231             0.018519
# BASEL_wind_speed                   0.003375            -0.001894
# BASEL_humidity                     0.045847             0.023917
# ...                                     ...                  ...
# VALENTIA_snow_depth               -0.007991             1.000000
# VALENTIA_sunshine                 -0.204202             0.000793
# VALENTIA_temp_mean                -0.039292            -0.077080
# VALENTIA_temp_min                 -0.019308            -0.072737
# VALENTIA_temp_max                 -0.065125            -0.071720
#
#                      VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# DATE                          0.002312            0.049756           0.060978
# MONTH                        -0.063997            0.260952           0.252235
# BASEL_cloud_cover            -0.054276           -0.229722          -0.205169
# BASEL_wind_speed             -0.026333           -0.066430          -0.049316
# BASEL_humidity               -0.161270           -0.215890          -0.185348
# ...                                ...                 ...                ...
# VALENTIA_snow_depth           0.000793           -0.077080          -0.072737
# VALENTIA_sunshine             1.000000            0.159709          -0.006798
# VALENTIA_temp_mean            0.159709            1.000000           0.942297
# VALENTIA_temp_min            -0.006798            0.942297           1.000000
# VALENTIA_temp_max             0.314919            0.925102           0.764379
#
#                      VALENTIA_temp_max
# DATE                          0.030676
# MONTH                         0.233360
# BASEL_cloud_cover            -0.231702
# BASEL_wind_speed             -0.086405
# BASEL_humidity               -0.227038
# ...                                ...
# VALENTIA_snow_depth          -0.071720
# VALENTIA_sunshine             0.314919
# VALENTIA_temp_mean            0.925102
# VALENTIA_temp_min             0.764379
# VALENTIA_temp_max             1.000000
#
# [170 rows x 170 columns]

# %% [markdown]
# ## Summary of Scaling and Checks

# %% [markdown]
# Everything seems to be in order so far. No lost data and all of it seems to have a standard deviation of 1.

# %% [markdown]
# # Changes after assignment approval

# %% [markdown]
# My suspicion to keep the DATE and MONTH columns away from scaling was correct. In order to bring those back into the final table I'll have to make some modifications.
#
# My first thought was concatenation, but, if I understand it correctly, data would be doubled when reintegrated and we don't want that. So I'm thinking merging is the next best bet.
#
# However, I'll need to drop the DATE and MONTH columns from the scaled data first so they can be replaced. I'll need to choose a common column to merge on between the two DataFrames. The "third" DataFrame only needs to be 3 columns (DATE, MONTH, and the shared column). Once that prep is done, I can merge them and export the frame as a new file for future assignments.
#
# My reasoning for this is not wanting to write the 168 columns to redo the scaling on the original dataframe.
#
# Sidenote: Bummer that .csv files don't save datetime attributes. It makes sense, but still sucks.
#
# Anyway, let's fix this stuff!

# %% [markdown]
# ## Drop DATE and MONTH from df_scaled

# %%
df_scaled_fixed = df_scaled.drop(columns = ['DATE', 'MONTH'])

# %% [markdown]
# ### Check

# %%
df_scaled_fixed.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0           0.660514          -0.02793        0.826097       -0.001949
# 1           0.244897          -0.02793        0.735760       -0.001949
# 2           1.076130          -0.02793        1.277781       -0.001949
# 3          -1.001953          -0.02793        1.458455       -0.001949
# 4           0.244897          -0.02793        1.729466       -0.001949
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0               -1.101066            -0.265148         -0.179228
# 1               -1.058108             1.658760         -0.179228
# 2               -1.251420             0.155707         -0.179228
# 3               -0.821838            -0.445514         -0.179228
# 4               -0.746661            -0.164944         -0.179228
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  ...  VALENTIA_cloud_cover  \
# 0       -0.902918        -0.528623       -0.845652  ...             -0.443701
# 1       -0.810126        -0.582946       -0.462450  ...              0.783085
# 2       -1.065304        -0.257010       -0.186545  ...              0.783085
# 3       -0.114186        -0.555784       -0.385810  ...              0.783085
# 4        0.187388        -1.003946       -1.075573  ...             -1.670486
#
#    VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0           0.761754          -1.299744                  -0.806427
# 1           1.183580          -1.262455                  -1.042055
# 2           1.183580          -0.432779                  -1.136306
# 3           0.480538           0.387574                  -1.183432
# 4          -0.363113           1.729970                  -0.794645
#
#    VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0               -0.088407            -0.024706           0.372147
# 1                0.503361            -0.024706          -0.829285
# 2               -0.396127            -0.024706          -1.009500
# 3                0.669056            -0.024706          -1.039536
# 4               -0.490810            -0.024706           0.672505
#
#    VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0           -0.668215          -0.519743          -0.752237
# 1           -0.548046          -0.629054          -0.407141
# 2           -0.067372           0.054135          -0.177078
# 3           -0.998679          -0.164486          -0.838511
# 4           -1.509396          -1.339569          -1.471186
#
# [5 rows x 168 columns]

# %% [markdown]
# Good to go!

# %% [markdown]
# ## Choose a shared column to merge on

# %% [markdown]
# I'll go with BASEL_cloud_cover simply because it's the 3rd column, haha. I'll write an empty line for copying purposes.

# %%
# BASEL_cloud_cover

# %% [markdown]
# ## New DataFrame based on the original with only DATE, MONTH, and BASEL_cloud_cover included

# %%
df_three_column = df[['DATE','MONTH','BASEL_cloud_cover']]

# %% [markdown]
# ### Check

# %%
df_three_column.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover
# 0  19600101      1                  7
# 1  19600102      1                  6
# 2  19600103      1                  8
# 3  19600104      1                  3
# 4  19600105      1                  6

# %%
df_three_column.shape
# Out:
# (22950, 3)

# %% [markdown]
# Good here too!

# %% [markdown]
# ## Merge DataFrames

# %%
df_scaled_merged = df_three_column.merge(df_scaled_fixed, on='BASEL_cloud_cover', how='outer')
# Out:
# C:\Users\rubix\AppData\Local\Temp\ipykernel_19248\1791522954.py:1: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_scaled_merged = df_three_column.merge(df_scaled_fixed, on='BASEL_cloud_cover', how='outer')

# %%
df_scaled_merged
# Out:
#              DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0             NaN    NaN          -2.248803          -0.02793       -2.245358
# 1             NaN    NaN          -2.248803          -0.02793       -1.161315
# 2             NaN    NaN          -2.248803          -0.02793        0.013064
# 3             NaN    NaN          -2.248803          -0.02793       -0.348283
# 4             NaN    NaN          -2.248803          -0.02793       -1.161315
# ...           ...    ...                ...               ...             ...
# 45895  20221011.0   10.0           8.000000               NaN             NaN
# 45896  20221013.0   10.0           8.000000               NaN             NaN
# 45897  20221014.0   10.0           8.000000               NaN             NaN
# 45898  20221020.0   10.0           8.000000               NaN             NaN
# 45899  20221021.0   10.0           8.000000               NaN             NaN
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           -0.001949               -0.220423            -0.445514
# 1           -0.001949               -0.220423            -0.445514
# 2           -0.001949               -0.198944            -0.445514
# 3           -0.001949                0.853532            -0.445514
# 4           -0.001949                1.261635            -0.445514
# ...               ...                     ...                  ...
# 45895             NaN                     NaN                  NaN
# 45896             NaN                     NaN                  NaN
# 45897             NaN                     NaN                  NaN
# 45898             NaN                     NaN                  NaN
# 45899             NaN                     NaN                  NaN
#
#        BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0             -0.179228        0.976121  ...             -2.283879
# 1             -0.179228        0.906527  ...             -1.057093
# 2             -0.179228        0.952923  ...              0.783085
# 3             -0.179228        1.347289  ...             -0.443701
# 4             -0.179228        1.625665  ...              0.783085
# ...                 ...             ...  ...                   ...
# 45895               NaN             NaN  ...                   NaN
# 45896               NaN             NaN  ...                   NaN
# 45897               NaN             NaN  ...                   NaN
# 45898               NaN             NaN  ...                   NaN
# 45899               NaN             NaN  ...                   NaN
#
#        VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0              -1.909805           2.522357                  -0.229137
# 1              -0.503721           1.963025                  -0.523673
# 2              -1.066155           0.629951                  -0.665050
# 3              -4.300148          -0.069214                   0.630907
# 4               0.199321          -1.309066                  -0.394077
# ...                  ...                ...                        ...
# 45895                NaN                NaN                        NaN
# 45896                NaN                NaN                        NaN
# 45897                NaN                NaN                        NaN
# 45898                NaN                NaN                        NaN
# 45899                NaN                NaN                        NaN
#
#        VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                   -0.490810            -0.024706           1.363329
# 1                   -0.490810            -0.024706           0.462254
# 2                   -0.419798            -0.024706          -0.949429
# 3                   -0.490810            -0.024706           0.342111
# 4                    1.177978            -0.024706          -1.039536
# ...                       ...                  ...                ...
# 45895                     NaN                  NaN                NaN
# 45896                     NaN                  NaN                NaN
# 45897                     NaN                  NaN                NaN
# 45898                     NaN                  NaN                NaN
# 45899                     NaN                  NaN                NaN
#
#        VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0               -1.749733          -1.940775          -1.298638
# 1               -2.380618          -2.268705          -2.132619
# 2               -1.839859          -1.804137          -1.643734
# 3                0.593556           0.327410           0.800693
# 4                0.082839           0.518703          -0.378383
# ...                   ...                ...                ...
# 45895                 NaN                NaN                NaN
# 45896                 NaN                NaN                NaN
# 45897                 NaN                NaN                NaN
# 45898                 NaN                NaN                NaN
# 45899                 NaN                NaN                NaN
#
# [45900 rows x 170 columns]

# %% [markdown]
# ## Notes

# %% [markdown]
# Okay, normally I would cut out all of the above because it's not useful to the final result, but I'll leave it in for teaching purposes.
#
# The BASEL_cloud_cover is actually NOT a shared column because it is mixing scaled and not scaled data. Back to the drawing board.
#
# ----------
#
# Okay, after some thinking/research I'm going to try something new.

# %% [markdown]
# ## Trying Something Different

# %%
# This should create a DataFrame called df_first_two that only contains values from the first two columns
df_first_two = df.iloc[:, :2]

# Let's check

# %%
df_first_two
# Out:
#            DATE  MONTH
# 0      19600101      1
# 1      19600102      1
# 2      19600103      1
# 3      19600104      1
# 4      19600105      1
# ...         ...    ...
# 22945  20221027     10
# 22946  20221028     10
# 22947  20221029     10
# 22948  20221030     10
# 22949  20221031     10
#
# [22950 rows x 2 columns]

# %% [markdown]
# Great! Easy enough so far.

# %%
# This code creates a new NumPy array (not particularly obvious compared to a df) called df_rest_scaled.
# However, it also REMOVES the first two columns in the scaling process.
# This is slightly counter-intuitive because while it is scaling data on only the selected columns the columns it doesn't scale are removed
# I would've thought that a selective modification would not change the rest of the data and that's why the next steps take place.

df_rest_scaled = scaler.fit_transform(df.iloc[:, 2:])

# %%
# This code is transforming the array back to a DataFrame while preserving the column names and row alignment via index.

df_rest_scaled = pd.DataFrame(df_rest_scaled, 
                              columns=df.columns[2:], 
                              index=df.index)

# %%
# This code merges the two DataFrames via concat

df_scaled_fixed = pd.concat([df_first_two, df_rest_scaled], axis=1)

# We can see the result here:

df_scaled_fixed
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0      19600101      1           0.660514          -0.02793        0.826097
# 1      19600102      1           0.244897          -0.02793        0.735760
# 2      19600103      1           1.076130          -0.02793        1.277781
# 3      19600104      1          -1.001953          -0.02793        1.458455
# 4      19600105      1           0.244897          -0.02793        1.729466
# ...         ...    ...                ...               ...             ...
# 22945  20221027     10          -1.833187          -0.02793        0.284075
# 22946  20221028     10           0.244897          -0.02793        0.103401
# 22947  20221029     10          -0.586336          -0.02793        0.013064
# 22948  20221030     10          -0.170720          -0.02793        0.374412
# 22949  20221031     10          -0.170720          -0.02793        0.735760
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           -0.001949               -1.101066            -0.265148
# 1           -0.001949               -1.058108             1.658760
# 2           -0.001949               -1.251420             0.155707
# 3           -0.001949               -0.821838            -0.445514
# 4           -0.001949               -0.746661            -0.164944
# ...               ...                     ...                  ...
# 22945        1.037367               -0.005632            -0.004619
# 22946        0.976231               -0.005632            -0.004619
# 22947        0.716402               -0.005632            -0.004619
# 22948        0.487141               -0.005632            -0.004619
# 22949        0.196744               -0.005632            -0.004619
#
#        BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0             -0.179228       -0.902918  ...             -0.443701
# 1             -0.179228       -0.810126  ...              0.783085
# 2             -0.179228       -1.065304  ...              0.783085
# 3             -0.179228       -0.114186  ...              0.783085
# 4             -0.179228        0.187388  ...             -1.670486
# ...                 ...             ...  ...                   ...
# 22945         -0.179228        0.720943  ...             -0.443701
# 22946         -0.179228        0.187388  ...             -0.443701
# 22947         -0.179228        0.349774  ...             -0.443701
# 22948         -0.179228        0.280180  ...             -0.443701
# 22949         -0.179228       -0.322968  ...             -0.443701
#
#        VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0               0.761754          -1.299744                  -0.806427
# 1               1.183580          -1.262455                  -1.042055
# 2               1.183580          -0.432779                  -1.136306
# 3               0.480538           0.387574                  -1.183432
# 4              -0.363113           1.729970                  -0.794645
# ...                  ...                ...                        ...
# 22945          -0.081896          -0.003958                  -0.005290
# 22946          -0.081896          -0.003958                  -0.005290
# 22947          -0.081896          -0.003958                  -0.005290
# 22948          -0.081896          -0.003958                  -0.005290
# 22949          -0.081896          -0.003958                  -0.005290
#
#        VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                   -0.088407            -0.024706           0.372147
# 1                    0.503361            -0.024706          -0.829285
# 2                   -0.396127            -0.024706          -1.009500
# 3                    0.669056            -0.024706          -1.039536
# 4                   -0.490810            -0.024706           0.672505
# ...                       ...                  ...                ...
# 22945               -0.005560            -0.024706          -0.018319
# 22946               -0.005560            -0.024706          -0.018319
# 22947               -0.005560            -0.024706          -0.018319
# 22948               -0.005560            -0.024706          -0.018319
# 22949               -0.005560            -0.024706          -0.018319
#
#        VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0               -0.668215          -0.519743          -0.752237
# 1               -0.548046          -0.629054          -0.407141
# 2               -0.067372           0.054135          -0.177078
# 3               -0.998679          -0.164486          -0.838511
# 4               -1.509396          -1.339569          -1.471186
# ...                   ...                ...                ...
# 22945           -0.007287          -0.000520          -0.004530
# 22946           -0.007287          -0.000520          -0.004530
# 22947           -0.007287          -0.000520          -0.004530
# 22948           -0.007287          -0.000520          -0.004530
# 22949           -0.007287          -0.000520          -0.004530
#
# [22950 rows x 170 columns]

# %% [markdown]
# Now we have scaled data while keeping DATE and MONTH "untouched." Time to export for future assignments.

# %% [markdown]
# # Export

# %%
df_scaled_fixed.to_csv(os.path.join(path, '02 Data','Prepared Data', 'weather_scaled.csv'), index=False)
